# %%
import matplotlib.pyplot as plt
import numpy as np

temperatures = [1200, 1100, 1000, 900, 800, 700, 600, 500, 400]
left_right_legs = np.array([
    [0.92185, 0.24260926],
    [0.95421042, 0.21672755],
    [0.95921146, 0.20970463],
    [0.97689329, 0.18821088],
    [0.98713623, 0.17844016],
    [0.99113715, 0.15611389],
    [0.99709039, 0.1451184],
    [0.99984965, 0.12411389],
    [1.0, 0.1026706]
])

left_right_legs_percent = left_right_legs * 100

alpha_1_antillon = [21.734341959520695, 19.051455039774446, 17.30440036250126, 15.35029201490283, 
                    14.554803141677576, 13.153886819051456, 11.027967979055482, 8.170123854596717, 6.599914409425033]
alpha_2_antillon = [94.15781391602054, 94.34724599738193, 95.78592286778773, 98.71047729332393, 
                    99.29702446883496, 99.66330178229786, 99.89238243882791, 99.93706575370054, 99.93454838384855]

joh_compositions = [25.5, 26.4, 28.7, 30.8, 35.5, 39.5, 81.3, 85.0, 90.8, 92.7, 93.7, 32, 40, 45, 50, 55, 65, 75, 90, 93.5, 26.8, 93.5]
joh_temperatures = [800, 820, 900, 916, 1025, 1060, 1060, 1025, 875, 820, 800, 968, 1080, 1108, 1125, 1145, 1150, 1140, 1025, 800, 800, 800]

ste_compositions = [25, 30, 33, 41, 81, 85, 94, 97, 95]
ste_temperatures = [680, 880, 960, 1060, 1100, 1060, 960, 880, 680]

dar_compositions = [49.2, 50.2, 52.2, 58.0, 59.2, 60.2, 62.2, 65.2, 70.2, 72.7, 27.9, 29.1, 33.6, 38.5, 41.8, 47.0, 52.8, 56.3, 66.4, 67.9, 73.4, 79.1, 83.3, 87.1, 91.9, 93.8]
dar_temperatures = [1229, 1238, 1244, 1252, 1260, 1258, 1257, 1248, 1243, 1233, 850, 900, 1000, 1100, 1150, 1200, 1225, 1250, 1225, 1200, 1200, 1150, 1100, 1000, 900, 850]

tie_compositions = [21.2, 23.2, 25.2, 27.2, 30.2, 33.2, 37.2, 89.1, 92.1, 96, 97, 98, 98, 99]
tie_temperatures = [510, 610, 705, 755, 810, 930, 1025, 1025, 930, 810, 755, 705, 610, 510]

rau_compositions = [21, 23]
rau_temperatures = [600, 800]

wic_compositions = [18.7, 20.0, 21.7, 23.0, 24.5, 26.5, 29.0, 30.0, 23, 25, 28, 38, 91, 93, 95]
wic_temperatures = [650, 700, 750, 800, 850, 900, 950, 970, 700, 800, 900, 1000, 900, 800, 700]

mun_compositions = [35.23, 40.24, 45.25, 50.25, 55.25, 58.25, 61.24, 63.24, 65.23, 67.22, 69.22, 71.21, 75.19, 80.16, 85.13]
mun_temperatures = [1080, 1140, 1180, 1217, 1238, 1250, 1249, 1248, 1242, 1237, 1226, 1208, 1180, 1148, 1035]

# Convert temperatures to Kelvin
joh_temperatures = [t + 273.15 for t in joh_temperatures]
ste_temperatures = [t + 273.15 for t in ste_temperatures]
dar_temperatures = [t + 273.15 for t in dar_temperatures]
tie_temperatures = [t + 273.15 for t in tie_temperatures]
rau_temperatures = [t + 273.15 for t in rau_temperatures]
wic_temperatures = [t + 273.15 for t in wic_temperatures]
mun_temperatures = [t + 273.15 for t in mun_temperatures]

plt.figure(figsize=(10, 6))

plt.scatter(left_right_legs_percent[:, 0], temperatures, label='This work (MC2)', color='blue', marker='o', s=100)
plt.scatter(left_right_legs_percent[:, 1], temperatures, color='blue', marker='o', s=100)
plt.scatter(alpha_1_antillon, temperatures, label='Antillon et al. 2024 (MC2)', edgecolors='red', facecolors='none', marker='s', s=100)
plt.scatter(alpha_2_antillon, temperatures, edgecolors='red', facecolors='none', marker='s', s=100)


plt.scatter(joh_compositions, joh_temperatures, label='Johansson et al. 1930 (Exp.)', edgecolors='green', facecolors='none', marker='^', s=100)
plt.scatter(ste_compositions, ste_temperatures, label='Stenzel et al. 1931 (Exp.)', edgecolors='orange', facecolors='none', marker='>', s=100)
plt.scatter(dar_compositions, dar_temperatures, label='Darling et al. 1952 (Exp.)', edgecolors='purple', facecolors='none', marker='<', s=100)
plt.scatter(tie_compositions, tie_temperatures, label='Tiedje et al. 1957 (Exp.)', edgecolors='brown', facecolors='none', marker='d', s=100)
plt.scatter(rau_compositions, rau_temperatures, label='Raub et al. 1964 (Exp.)', edgecolors='cyan', facecolors='none', marker='p', s=100)
plt.scatter(wic_compositions, wic_temperatures, label='Wictorin et al. 1938, 1947, 1949 (Exp.)', edgecolors='magenta', facecolors='none', marker='H', s=100)
plt.scatter(mun_compositions, mun_temperatures, label='Munster et al. 1960 (Exp.)', edgecolors='teal', facecolors='none', marker='*', s=100)

plt.ylabel('Temperature (K)', fontsize=14)
plt.xlabel('%Pt Composition', fontsize=14)
plt.title('Phase Diagram: Temperature vs. %Pt Composition', fontsize=16)
plt.xlim(0, 100)
plt.ylim(350, 1600)
plt.legend(loc='lower center', fontsize=10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt


x_w00 = [26.28236711008923, 24.852952804997475, 18.61827338917173, 14.979045394548761, 
         15.578791141280876, 14.705327761658848, 15.38475575263225, 28.76529017110393, 
         32.087613972981025, 99.89172946965687, 67.26397936777309, 99.8759146730899, 
         99.82907854479541, 99.21412626290274, 98.53044044208438, 97.35588766628345, 
         68.6094535987786, 68.55166876516851]
y_w00 = [400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 
         900, 1000, 1100, 1200]


x_user = [10.26706, 12.411389, 14.51184, 15.611389, 17.844016, 18.821088, 20.970463, 
          21.672755, 24.260926, 92.185, 95.421042, 95.921146, 97.689329, 98.713623, 
          99.113715, 99.709039, 99.984965, 100.0]
y_user = [400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1200, 1100, 1000, 900, 800, 
          700, 600, 500, 400]


x_w25 = [24.676723482197733, 27.514254592808506, 13.85296927579975, 14.965953277795697, 
         15.42477773788588, 14.968995880316188, 27.522165359361786, 29.697626161513515, 
         32.26984233233739, 67.23177937480604, 67.36747944721998, 99.91237304740984, 
         99.69634826845491, 99.31663147389752, 98.74705628206144, 70.65166460783897, 
         69.53989764685122, 69.36160113915038]
y_w25 = [400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 
         900, 1000, 1100, 1200]


x_w50 = [
    28.340016916870017, 11.149312676090622, 13.235320964139888, 13.60347586911941, 
    13.849318152775158, 16.259059349004765, 17.292935685467924, 18.829449958316346, 
    24.494167330968217, 67.3248830119331, 99.97261657731558, 99.90324523984836, 
    99.87707885817213, 99.45963379236063, 98.40750184077453, 97.59634400881139, 
    91.75576421047508, 81.53079418010991
]
y_w50 = [
    400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 900, 
    1000, 1100, 1200
]


x_w75 = [
    5.8424053598486, 7.938149975963441, 11.256412284811937, 13.568790200385802, 
    14.254592808504682, 18.19415455203763, 19.007137945513076, 19.451357913504896, 
    22.9546104555993, 99.94340759311885, 99.83752502540574, 99.82839721784426, 
    99.65314331266393, 98.9807281556352, 99.05679321864751, 98.09167969914746, 
    96.96835084858185, 97.41926454211875
]
y_w75 = [
    400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 900, 
    1000, 1100, 1200
]


x_w100 = [
    5.586826748127279, 48.8130807567561, 49.48488739328072, 49.34431915683399, 
    50.024645080415986, 49.536003115624986, 49.82930999860041, 50.56866241107994, 
    49.70578033626843, 99.98296142588525, 100.09797180115984, 99.98600402840574, 
    99.89837707581557, 99.97565917983607, 99.90020263732787, 99.80649047969672, 
    99.65253479215983, 99.43590149270081
]
y_w100 = [
    400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 900, 
    1000, 1100, 1200
]

plt.figure(figsize=(10, 6))

plt.scatter(x_user, y_user, color='blue', marker='o', label='This work')
plt.plot([x_user[i] for i in range(len(x_user)) if x_user[i] < 50], [y_user[i] for i in range(len(x_user)) if x_user[i] < 50], 'blue', linestyle='-')
plt.plot([x_user[i] for i in range(len(x_user)) if x_user[i] > 50], [y_user[i] for i in range(len(x_user)) if x_user[i] > 50], 'blue', linestyle='-')

plt.scatter(x_w00, y_w00, facecolors='none', edgecolors='black', marker='v', label='w=0.00')
plt.plot([x_w00[i] for i in range(len(x_w00)) if x_w00[i] < 50], [y_w00[i] for i in range(len(x_w00)) if x_w00[i] < 50], 'black', linestyle=':')
plt.plot([x_w00[i] for i in range(len(x_w00)) if x_w00[i] > 50], [y_w00[i] for i in range(len(x_w00)) if x_w00[i] > 50], 'black', linestyle=':')

plt.scatter(x_w25, y_w25, facecolors='none', edgecolors='orange', marker='v', label='w=0.25')
plt.plot([x_w25[i] for i in range(len(x_w25)) if x_w25[i] < 50], [y_w25[i] for i in range(len(x_w25)) if x_w25[i] < 50], 'orange', linestyle=':')
plt.plot([x_w25[i] for i in range(len(x_w25)) if x_w25[i] > 50], [y_w25[i] for i in range(len(x_w25)) if x_w25[i] > 50], 'orange', linestyle=':')

plt.scatter(x_w50, y_w50, facecolors='none', edgecolors='green', marker='D', label='w=0.50')
plt.plot([x_w50[i] for i in range(len(x_w50)) if x_w50[i] < 50], [y_w50[i] for i in range(len(x_w50)) if x_w50[i] < 50], 'green', linestyle=':')
plt.plot([x_w50[i] for i in range(len(x_w50)) if x_w50[i] > 50], [y_w50[i] for i in range(len(x_w50)) if x_w50[i] > 50], 'green', linestyle=':')


plt.scatter(x_w75, y_w75, facecolors='none', edgecolors='red', marker='s', label='w=0.75')
plt.plot([x_w75[i] for i in range(len(x_w75)) if x_w75[i] < 50], [y_w75[i] for i in range(len(x_w75)) if x_w75[i] < 50], 'red', linestyle=':')
plt.plot([x_w75[i] for i in range(len(x_w75)) if x_w75[i] > 50], [y_w75[i] for i in range(len(x_w75)) if x_w75[i] > 50], 'red', linestyle=':')


plt.scatter(x_w100, y_w100, facecolors='none', edgecolors='purple', marker='o', label='w=1.00')
plt.plot([x_w100[i] for i in range(len(x_w100)) if x_w100[i] < 60], [y_w100[i] for i in range(len(x_w100)) if x_w100[i] < 60], 'purple', linestyle=':')
plt.plot([x_w100[i] for i in range(len(x_w100)) if x_w100[i] > 60], [y_w100[i] for i in range(len(x_w100)) if x_w100[i] > 60], 'purple', linestyle=':')

plt.ylabel('Temperature (K)')
plt.xlabel('Composition of Pt (%)')
plt.title('Phase Diagram of Pt and Au')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# User data
x_user = [10.26706, 12.411389, 14.51184, 15.611389, 17.844016, 18.821088, 20.970463, 
          21.672755, 24.260926, 92.185, 95.421042, 95.921146, 97.689329, 98.713623, 
          99.113715, 99.709039, 99.984965, 100.0]
y_user = [400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1200, 1100, 1000, 900, 800, 
          700, 600, 500, 400]

# Literature values for different w-factors
x_w00 = [26.28236711008923, 24.852952804997475, 18.61827338917173, 14.979045394548761, 
         15.578791141280876, 14.705327761658848, 15.38475575263225, 28.76529017110393, 
         32.087613972981025, 99.89172946965687, 67.26397936777309, 99.8759146730899, 
         99.82907854479541, 99.21412626290274, 98.53044044208438, 97.35588766628345, 
         68.6094535987786, 68.55166876516851]
y_w00 = [400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 
         900, 1000, 1100, 1200]

x_w25 = [24.676723482197733, 27.514254592808506, 13.85296927579975, 14.965953277795697, 
         15.42477773788588, 14.968995880316188, 27.522165359361786, 29.697626161513515, 
         32.26984233233739, 67.23177937480604, 67.36747944721998, 99.91237304740984, 
         99.69634826845491, 99.31663147389752, 98.74705628206144, 70.65166460783897, 
         69.53989764685122, 69.36160113915038]
y_w25 = [400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 
         900, 1000, 1100, 1200]

x_w50 = [
    28.340016916870017, 11.149312676090622, 13.235320964139888, 13.60347586911941, 
    13.849318152775158, 16.259059349004765, 17.292935685467924, 18.829449958316346, 
    24.494167330968217, 67.3248830119331, 99.97261657731558, 99.90324523984836, 
    99.87707885817213, 99.45963379236063, 98.40750184077453, 97.59634400881139, 
    91.75576421047508, 81.53079418010991
]
y_w50 = [
    400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 900, 
    1000, 1100, 1200
]

x_w75 = [
    5.8424053598486, 7.938149975963441, 11.256412284811937, 13.568790200385802, 
    14.254592808504682, 18.19415455203763, 19.007137945513076, 19.451357913504896, 
    22.9546104555993, 99.94340759311885, 99.83752502540574, 99.82839721784426, 
    99.65314331266393, 98.9807281556352, 99.05679321864751, 98.09167969914746, 
    96.96835084858185, 97.41926454211875
]
y_w75 = [
    400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 900, 
    1000, 1100, 1200
]

x_w100 = [
    5.586826748127279, 48.8130807567561, 49.48488739328072, 49.34431915683399, 
    50.024645080415986, 49.536003115624986, 49.82930999860041, 50.56866241107994, 
    49.70578033626843, 99.98296142588525, 100.09797180115984, 99.98600402840574, 
    99.89837707581557, 99.97565917983607, 99.90020263732787, 99.80649047969672, 
    99.65253479215983, 99.43590149270081
]
y_w100 = [
    400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 400, 500, 600, 700, 800, 900, 
    1000, 1100, 1200
]

# Experimental data
joh_compositions = [25.5, 26.4, 28.7, 30.8, 35.5, 39.5, 81.3, 85.0, 90.8, 92.7, 93.7, 32, 40, 45, 50, 55, 65, 75, 90, 93.5, 26.8, 93.5]
joh_temperatures = [1073, 1093, 1173, 1189, 1298, 1333, 1333, 1298, 1148, 1093, 1073, 1241, 1353, 1371, 1398, 1418, 1423, 1413, 1298, 1073, 1073, 1073]

ste_compositions = [25, 30, 33, 41, 81, 85, 94, 97, 95]
ste_temperatures = [953, 1153, 1233, 1353, 1373, 1333, 1233, 1153, 953]

dar_compositions = [49.2, 50.2, 52.2, 58.0, 59.2, 60.2, 62.2, 65.2, 70.2, 72.7, 27.9, 29.1, 33.6, 38.5, 41.8, 47.0, 52.8, 56.3, 66.4, 67.9, 73.4, 79.1, 83.3, 87.1, 91.9, 93.8]
dar_temperatures = [1502, 1511, 1517, 1525, 1533, 1531, 1530, 1521, 1516, 1506, 1123, 1173, 1273, 1373, 1423, 1473, 1498, 1523, 1498, 1473, 1473, 1423, 1373, 1273, 1173, 1123]

tie_compositions = [21.2, 23.2, 25.2, 27.2, 30.2, 33.2, 37.2, 89.1, 92.1, 96, 97, 98, 98, 99]
tie_temperatures = [783, 883, 978, 1028, 1083, 1203, 1298, 1298, 1203, 1083, 1028, 978, 883, 783]

rau_compositions = [21, 23]
rau_temperatures = [873, 1073]

wic_compositions = [18.7, 20.0, 21.7, 23.0, 24.5, 26.5, 29.0, 30.0, 23, 25, 28, 38, 91, 93, 95]
wic_temperatures = [923, 973, 1023, 1073, 1123, 1173, 1223, 1243, 973, 1073, 1173, 1273, 1173, 1073, 973]

mun_compositions = [35.23, 40.24, 45.25, 50.25, 55.25, 58.25, 61.24, 63.24, 65.23, 67.22, 69.22, 71.21, 75.19, 80.16, 85.13]
mun_temperatures = [1353, 1413, 1453, 1490, 1511, 1523, 1522, 1521, 1515, 1510, 1499, 1481, 1453, 1418, 1305]

# Plotting the data
plt.figure(figsize=(14, 8))

# User's combined data with solid markers and lines, labeled "This work"
plt.scatter(x_user, y_user, color='blue', marker='o', label='This work')
plt.plot([x_user[i] for i in range(len(x_user)) if x_user[i] < 60], [y_user[i] for i in range(len(x_user)) if x_user[i] < 60], 'blue', linestyle='-')
plt.plot([x_user[i] for i in range(len(x_user)) if x_user[i] > 60], [y_user[i] for i in range(len(x_user)) if x_user[i] > 60], 'blue', linestyle='-')

# w=0.00 data with black hollow triangles and dotted lines
plt.scatter(x_w00, y_w00, facecolors='none', edgecolors='black', marker='v', label='w=0.00')
plt.plot([x_w00[i] for i in range(len(x_w00)) if x_w00[i] < 60], [y_w00[i] for i in range(len(x_w00)) if x_w00[i] < 60], 'black', linestyle=':')
plt.plot([x_w00[i] for i in range(len(x_w00)) if x_w00[i] > 60], [y_w00[i] for i in range(len(x_w00)) if x_w00[i] > 60], 'black', linestyle=':')

# w=0.25 data with orange hollow triangles and dotted lines
plt.scatter(x_w25, y_w25, facecolors='none', edgecolors='orange', marker='v', label='w=0.25')
plt.plot([x_w25[i] for i in range(len(x_w25)) if x_w25[i] < 60], [y_w25[i] for i in range(len(x_w25)) if x_w25[i] < 60], 'orange', linestyle=':')
plt.plot([x_w25[i] for i in range(len(x_w25)) if x_w25[i] > 60], [y_w25[i] for i in range(len(x_w25)) if x_w25[i] > 60], 'orange', linestyle=':')

# w=0.50 data with green hollow diamonds and dotted lines
plt.scatter(x_w50, y_w50, facecolors='none', edgecolors='green', marker='D', label='w=0.50')
plt.plot([x_w50[i] for i in range(len(x_w50)) if x_w50[i] < 60], [y_w50[i] for i in range(len(x_w50)) if x_w50[i] < 60], 'green', linestyle=':')
plt.plot([x_w50[i] for i in range(len(x_w50)) if x_w50[i] > 60], [y_w50[i] for i in range(len(x_w50)) if x_w50[i] > 60], 'green', linestyle=':')

# w=0.75 data with red filled squares and solid lines
plt.scatter(x_w75, y_w75, color='red', marker='s', label='w=0.75')
plt.plot([x_w75[i] for i in range(len(x_w75)) if x_w75[i] < 60], [y_w75[i] for i in range(len(x_w75)) if x_w75[i] < 60], 'red', linestyle='-')
plt.plot([x_w75[i] for i in range(len(x_w75)) if x_w75[i] > 60], [y_w75[i] for i in range(len(x_w75)) if x_w75[i] > 60], 'red', linestyle='-')

# w=1.00 data with purple hollow circles and dotted lines
plt.scatter(x_w100, y_w100, facecolors='none', edgecolors='purple', marker='o', label='w=1.00')
plt.plot([x_w100[i] for i in range(len(x_w100)) if x_w100[i] < 60], [y_w100[i] for i in range(len(x_w100)) if x_w100[i] < 60], 'purple', linestyle=':')
plt.plot([x_w100[i] for i in range(len(x_w100)) if x_w100[i] > 60], [y_w100[i] for i in range(len(x_w100)) if x_w100[i] > 60], 'purple', linestyle=':')

# Adding the experimental data sets
plt.scatter(joh_compositions, joh_temperatures, label='Johansson et al. 1930 (Exp.)', edgecolors='green', facecolors='none', marker='^', s=100)
plt.scatter(ste_compositions, ste_temperatures, label='Stenzel et al. 1931 (Exp.)', edgecolors='orange', facecolors='none', marker='>', s=100)
plt.scatter(dar_compositions, dar_temperatures, label='Darling et al. 1952 (Exp.)', edgecolors='purple', facecolors='none', marker='<', s=100)
plt.scatter(tie_compositions, tie_temperatures, label='Tiedje et al. 1957 (Exp.)', edgecolors='brown', facecolors='none', marker='d', s=100)
plt.scatter(rau_compositions, rau_temperatures, label='Raub et al. 1964 (Exp.)', edgecolors='cyan', facecolors='none', marker='p', s=100)
plt.scatter(wic_compositions, wic_temperatures, label='Wictorin et al. 1938, 1947, 1949 (Exp.)', edgecolors='magenta', facecolors='none', marker='H', s=100)
plt.scatter(mun_compositions, mun_temperatures, label='Munster et al. 1960 (Exp.)', edgecolors='teal', facecolors='none', marker='*', s=100)

plt.ylabel('Temperature (K)', fontsize=14)
plt.xlabel('%Pt Composition', fontsize=14)
plt.title('Phase Diagram: Temperature vs. %Pt Composition', fontsize=16)
plt.xlim(0, 100)
plt.ylim(350, 1600)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2, fontsize=10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)
plt.show()

# %%
NOW RUNNING TEMPERATURE = 400K
-8642.009630779785
alpha_1 Phase Percent: 39.1%, Lattice Type: fcc, 
Composition: 99.546% Pt; 0.45436% Au
alpha_2 Phase Percent: 60.9%, Lattice Type: fcc, 
Composition: 18.187% Pt; 81.813% Au
NOW RUNNING TEMPERATURE = 500K
-8642.009630779785
alpha_1 Phase Percent: 39.242%, Lattice Type: fcc, 
Composition: 97.555% Pt; 2.445% Au
alpha_2 Phase Percent: 60.758%, Lattice Type: fcc, 
Composition: 19.283% Pt; 80.717% Au
NOW RUNNING TEMPERATURE = 600K
-8642.009630779785
alpha_1 Phase Percent: 39.18%, Lattice Type: fcc, 
Composition: 96.06% Pt; 3.9398% Au
alpha_2 Phase Percent: 60.82%, Lattice Type: fcc, 
Composition: 20.328% Pt; 79.672% Au
NOW RUNNING TEMPERATURE = 700K
-8642.009630779785
alpha_1 Phase Percent: 39.469%, Lattice Type: fcc, 
Composition: 92.626% Pt; 7.3737% Au
alpha_2 Phase Percent: 60.531%, Lattice Type: fcc, 
Composition: 22.204% Pt; 77.796% Au
NOW RUNNING TEMPERATURE = 800K
-8642.009630779785
alpha_1 Phase Percent: 40.162%, Lattice Type: fcc, 
Composition: 88.12% Pt; 11.88% Au
alpha_2 Phase Percent: 59.838%, Lattice Type: fcc, 
Composition: 24.411% Pt; 75.589% Au
NOW RUNNING TEMPERATURE = 900K
-8642.009630779785
alpha_1 Phase Percent: 41.234%, Lattice Type: fcc, 
Composition: 81.26% Pt; 18.74% Au
alpha_2 Phase Percent: 58.766%, Lattice Type: fcc, 
Composition: 28.069% Pt; 71.931% Au
NOW RUNNING TEMPERATURE = 1000K
-8642.009630779785
